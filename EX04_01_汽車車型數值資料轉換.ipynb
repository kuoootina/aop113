# %% [markdown]
# <a href="https://colab.research.google.com/github/kuoootina/aop113/blob/main/EX04_01_%E6%B1%BD%E8%BB%8A%E8%BB%8A%E5%9E%8B%E6%95%B8%E5%80%BC%E8%B3%87%E6%96%99%E8%BD%89%E6%8F%9B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -O car_models.csv https://raw.githubusercontent.com/imchihchao/aop113b/main/materials/04-car_models.csv
# Out:
# --2025-05-20 08:06:34--  https://raw.githubusercontent.com/imchihchao/aop113b/main/materials/04-car_models.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16783 (16K) [text/plain]
# Saving to: ‘car_models.csv’
#
# car_models.csv      100%[===================>]  16.39K  --.-KB/s    in 0.004s
#
# 2025-05-20 08:06:34 (3.73 MB/s) - ‘car_models.csv’ saved [16783/16783]

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/imchihchao/aop113b/main/materials/04-car_models.csv'
df = pd.read_csv(url)
df
# Out:
#                     名稱  哩/加侖  氣缸  排氣量     馬力    重量  加速時間   年份
# 0         Honda FozElU  47.6   4  345   66.0  3844  24.8   64
# 1         Lexus ZCKlVx  36.9   2  304   92.0  4733  25.5   93
# 2         Lexus pBOMcW  13.2  10  193  103.0  3496  29.6   71
# 3          Audi uFi6qm  58.5  10  148   50.0  4884  16.1   84
# 4           BMW YLHFKB  30.6   6  294  146.0  2387  24.6   67
# ..                 ...   ...  ..  ...    ...   ...   ...  ...
# 375  Volkswagen cabTUk  38.4   4  304   90.0  3734  12.3   61
# 376  Volkswagen 6Sqvm1  20.6   6  244   52.0  2941  25.8  106
# 377        Ford DQsLtx  58.3   4  266   76.0  3999  14.4  106
# 378        Benz v615Pa  32.7   8  124  100.0  3005  24.4   89
# 379        Ford dbU4PW  24.3   6   76   94.0  3488  28.5   66
#
# [380 rows x 8 columns]

# %%
df_std = df.drop(columns='名稱')
df_mms = df.drop(columns='名稱')

# %%
df.columns.to_list()
# Out:
# ['名稱', '哩/加侖', '氣缸', '排氣量', '馬力', '重量', '加速時間', '年份']

# %%
df[['哩/加侖', '氣缸', '排氣量', '馬力', '重量', '加速時間', '年份']]
# Out:
#      哩/加侖  氣缸  排氣量     馬力    重量  加速時間   年份
# 0    47.6   4  345   66.0  3844  24.8   64
# 1    36.9   2  304   92.0  4733  25.5   93
# 2    13.2  10  193  103.0  3496  29.6   71
# 3    58.5  10  148   50.0  4884  16.1   84
# 4    30.6   6  294  146.0  2387  24.6   67
# ..    ...  ..  ...    ...   ...   ...  ...
# 375  38.4   4  304   90.0  3734  12.3   61
# 376  20.6   6  244   52.0  2941  25.8  106
# 377  58.3   4  266   76.0  3999  14.4  106
# 378  32.7   8  124  100.0  3005  24.4   89
# 379  24.3   6   76   94.0  3488  28.5   66
#
# [380 rows x 7 columns]

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
df_std[ df_std.columns.to_list() ] = std.fit_transform(  df_std[ df_std.columns.to_list() ]  )
df_std
# Out:
#          哩/加侖        氣缸       排氣量        馬力        重量      加速時間        年份
# 0    0.869516 -0.601421  1.252985 -1.203924  0.402812  0.815578 -1.458241
# 1    0.107154 -1.306791  0.835064 -0.394976  1.436746  0.941139  0.401907
# 2   -1.581441  1.514689 -0.296381 -0.052729 -0.001922  1.676566 -1.009240
# 3    1.646127  1.514689 -0.755074 -1.701739  1.612363 -0.744962 -0.175381
# 4   -0.341713  0.103949  0.733132  1.285147 -1.291722  0.779704 -1.265812
# ..        ...       ...       ...       ...       ...       ...       ...
# 375  0.214027 -0.601421  0.835064 -0.457203  0.274879 -1.426577 -1.650670
# 376 -1.054200  0.103949  0.223472 -1.639512 -0.647404  0.994951  1.235766
# 377  1.631877 -0.601421  0.447723 -0.892790  0.583082 -1.049895  1.235766
# 378 -0.192090  0.809319 -0.999711 -0.146069 -0.572970  0.743829  0.145335
# 379 -0.790580  0.103949 -1.488985 -0.332749 -0.011226  1.479256 -1.329955
#
# [380 rows x 7 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
mms = MinMaxScaler()
df_mms[ df_mms.columns.to_list() ] = mms.fit_transform( df_mms[ df_mms.columns.to_list() ] )
