# %% [markdown]
# <a href="https://colab.research.google.com/github/kuoootina/aop113/blob/main/EX03_03_%E7%A9%BA%E6%B0%A3%E5%93%81%E8%B3%AA%E6%8C%87%E6%A8%99(AQI).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = 'https://data.moenv.gov.tw/api/v2/aqx_p_432?api_key=9e565f9a-84dd-4e79-9097-d403cae1ea75&limit=1000&sort=ImportDate%20desc&format=CSV'
df = pd.read_csv(url)
df.head()
# Out:
#   sitename county  aqi pollutant    status  so2    co    o3  o3_8hr   pm10  \
# 0       基隆    基隆市   93      懸浮微粒        普通  NaN   NaN  79.0      59   67.0
# 1       汐止    新北市  101      懸浮微粒  對敏感族群不健康  1.8  0.22  76.0      49   75.0
# 2       萬里    新北市  109      懸浮微粒  對敏感族群不健康  1.2  0.32  81.0      67  102.0
# 3       新店    新北市  102      懸浮微粒  對敏感族群不健康  1.6  0.33  75.0      52   82.0
# 4       土城    新北市  104      懸浮微粒  對敏感族群不健康  1.3  0.28  76.0      49   81.0
#
#    ...  wind_speed  wind_direc          publishtime  co_8hr pm2.5_avg  \
# 0  ...         4.4          89  2025/04/15 14:00:00     0.2      20.7
# 1  ...         2.4          11  2025/04/15 14:00:00     0.2      20.1
# 2  ...         4.3          70  2025/04/15 14:00:00     0.3      19.0
# 3  ...         2.7           8  2025/04/15 14:00:00     0.3      18.2
# 4  ...         2.7          62  2025/04/15 14:00:00     0.3      21.9
#
#   pm10_avg so2_avg   longitude   latitude  siteid
# 0       69       2  121.760056  25.129167       1
# 1       76       1  121.640810  25.066240       2
# 2       94       1  121.689881  25.179667       3
# 3       79       1  121.537778  24.977222       4
# 4       83       1  121.451861  24.982528       5
#
# [5 rows x 24 columns]

# %% [markdown]
# 留下需要的欄位（'sitename', 'county','pollutant', 'status', 'aqi'）

# %%
df = df[['sitename', 'county', 'pollutant', 'aqi']]
df.head()
# Out:
#   sitename county pollutant  aqi
# 0       基隆    基隆市      懸浮微粒   93
# 1       汐止    新北市      懸浮微粒  101
# 2       萬里    新北市      懸浮微粒  109
# 3       新店    新北市      懸浮微粒  102
# 4       土城    新北市      懸浮微粒  104

# %% [markdown]
# 請找出除了空氣品質不良的測站（aqi > 100）

# %%
condition = df['aqi'] > 100
df[condition]
# Out:
#        sitename county  aqi pollutant    status  so2    co     o3  o3_8hr  \
# 1            汐止    新北市  101      懸浮微粒  對敏感族群不健康  1.8  0.22   76.0      49
# 2            萬里    新北市  109      懸浮微粒  對敏感族群不健康  1.2  0.32   81.0      67
# 3            新店    新北市  102      懸浮微粒  對敏感族群不健康  1.6  0.33   75.0      52
# 4            土城    新北市  104      懸浮微粒  對敏感族群不健康  1.3  0.28   76.0      49
# 5            板橋    新北市  103      懸浮微粒  對敏感族群不健康  2.1  0.31   75.0      49
# ..          ...    ...  ...       ...       ...  ...   ...    ...     ...
# 81       臺南（麻豆）    臺南市  114      懸浮微粒  對敏感族群不健康  2.2  0.18   73.0      47
# 82       屏東（琉球）    屏東縣  120      懸浮微粒  對敏感族群不健康  2.2  0.25   93.0      67
# 83  台中市（和平區消防隊）    臺中市  104      懸浮微粒  對敏感族群不健康  1.0  0.27   80.0      47
# 84       新北（樹林）    新北市  104      懸浮微粒  對敏感族群不健康  0.7  0.32   75.0      39
# 86       屏東(枋山)    屏東縣  108        臭氧  對敏感族群不健康  2.0  0.28  106.0      67
#
#      pm10  ...  wind_speed  wind_direc          publishtime  co_8hr pm2.5_avg  \
# 1    75.0  ...         2.4          11  2025/04/15 14:00:00     0.2      20.1
# 2   102.0  ...         4.3          70  2025/04/15 14:00:00     0.3      19.0
# 3    82.0  ...         2.7           8  2025/04/15 14:00:00     0.3      18.2
# 4    81.0  ...         2.7          62  2025/04/15 14:00:00     0.3      21.9
# 5    81.0  ...         1.9          54  2025/04/15 14:00:00     0.4      19.5
# ..    ...  ...         ...         ...                  ...     ...       ...
# 81  138.0  ...         4.1           1  2025/04/15 14:00:00     0.2      24.6
# 82  115.0  ...         0.8         229  2025/04/15 14:00:00     0.3      28.3
# 83  105.0  ...         0.6         340  2025/04/15 14:00:00     0.2      22.4
# 84   85.0  ...         0.3         195  2025/04/15 14:00:00     0.4      20.9
# 86  103.0  ...         2.9         325  2025/04/15 14:00:00     0.1      21.3
#
#    pm10_avg so2_avg   longitude   latitude  siteid
# 1        76       1  121.640810  25.066240       2
# 2        94       1  121.689881  25.179667       3
# 3        79       1  121.537778  24.977222       4
# 4        83       1  121.451861  24.982528       5
# 5        81       1  121.458667  25.012972       6
# ..      ...     ...         ...        ...     ...
# 81      107       1  120.245831  23.179047     203
# 82      121       2  120.377220  22.352220     204
# 83       82       0  120.883858  24.174592     310
# 84       83       0  121.383528  24.949028     311
# 86       85       0  120.651472  22.260899     313
#
# [82 rows x 24 columns]

# %% [markdown]
# 查詢空氣污染指標物（pollutant）有那些？

# %%
df['pollutant'].unique()
# Out:
# array(['懸浮微粒', '細懸浮微粒', '臭氧八小時', '臭氧'], dtype=object)

# %% [markdown]
# 請找出高雄市的測站資料

# %%
condition = df['county'] =='高雄市'
df[condition]
# Out:
#    sitename county pollutant  aqi
# 46       美濃    高雄市      懸浮微粒   84
# 47       橋頭    高雄市      懸浮微粒  110
# 48       仁武    高雄市      懸浮微粒  110
# 49       鳳山    高雄市      懸浮微粒  115
# 50       大寮    高雄市      懸浮微粒  107
# 51       林園    高雄市      懸浮微粒  112
# 52       楠梓    高雄市      懸浮微粒  113
# 53       左營    高雄市      懸浮微粒  114
# 54       前金    高雄市      懸浮微粒  114
# 55       前鎮    高雄市      懸浮微粒  122
# 56       小港    高雄市      懸浮微粒  111
# 69       復興    高雄市      懸浮微粒  110
# 80   高雄（湖內）    高雄市      懸浮微粒  109

# %% [markdown]
# 計算各縣市的平均

# %%
df.groupby('county')['aqi'].mean().sort_values(ascending=False)
# Out:
# county
# 金門縣    136.000000
# 澎湖縣    119.000000
# 嘉義縣    116.000000
# 彰化縣    115.400000
# 雲林縣    115.250000
# 臺中市    114.166667
# 苗栗縣    112.666667
# 新竹縣    112.500000
# 嘉義市    112.000000
# 新竹市    111.000000
# 臺南市    110.500000
# 高雄市    110.076923
# 桃園市    110.000000
# 連江縣    109.000000
# 南投縣    107.666667
# 屏東縣    106.600000
# 新北市    105.615385
# 宜蘭縣    104.333333
# 花蓮縣    104.000000
# 臺北市    104.000000
# 基隆市     93.000000
# 臺東縣     88.500000
# Name: aqi, dtype: float64
